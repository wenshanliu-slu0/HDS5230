# %% [markdown]
# ##### Week3 Assignment
# ##### Author:Wenshan, Liu
# ##### Date: 2025-02-09

# %%
import numpy as np
import time
from scipy.spatial.distance import cdist
import pandas as pd
import cProfile

# %%
# load data into dataframe
df_cleaned = pd.read_csv("clinics.csv", sep="|")
print(df_cleaned.head())
# Out:
#    bizID   bizCat                  bizCatSub  \
# 0      1  Clinics                    Clinics
# 1      2  Clinics                    Clinics
# 2      3  Clinics  Clinics & Medical Centers
# 3      4  Clinics  Clinics & Medical Centers
# 4      5  Clinics  Clinics & Medical Centers
#
#                                      bizName  \
# 0                           Hino Ronald H MD
# 1                         Farmer Joesph F Md
# 2                             Najjar Fadi Md
# 3  Kittson Memorial Upper Level Nursing Home
# 4                       Thompson Robert B Md
#
#                              bizAddr      bizCity bizState  bizZip  \
# 0  98-151 Pali Momi Street Suite 142         Aiea       HI   96701
# 1            1225 Breckenridge Drive  Little Rock       AR   72205
# 2     1155 West Linda Avenue Suite B    Hermiston       OR   97838
# 3            1010 South Birch Avenue      Hallock       MN   56728
# 4        100 North Eagle Creek Drive    Lexington       KY   40509
#
#         bizPhone  bizFax  ...                   bizURL locAreaCode  locFIPS  \
# 0  (808)487-2477     NaN  ...                      NaN         808    15003
# 1  (501)225-2594     NaN  ...                      NaN         501     5119
# 2  (541)289-1122     NaN  ...                      NaN         541    41059
# 3  (218)843-2525     NaN  ...                      NaN         218    27069
# 4  (859)258-4000     NaN  ...  www.lexingtonclinic.com         859    21067
#
#    locTimeZone locDST   locLat   locLong  locMSA  locPMSA  locCounty
# 0        PST-2      N  21.3980 -157.8981  3320.0      NaN   Honolulu
# 1          CST      Y  34.7495  -92.3533  4400.0      NaN    Pulaski
# 2          PST      Y  45.8456 -119.2817     NaN      NaN   Umatilla
# 3          CST      Y  48.7954  -97.0090     NaN      NaN    Kittson
# 4          EST      Y  37.9935  -84.3712  4280.0      NaN    Fayette
#
# [5 rows x 21 columns]

# %%
# get latitudes and longitudes and drop na values
latitudes = df_cleaned["locLat"].dropna().values
longitudes = df_cleaned["locLong"].dropna().values
coordinates = np.column_stack((latitudes, longitudes))

# %%
# to create a distance function

def haversine(lat1, lon1, lat2, lon2):
    MILES = 3959  # to set the radius of the earth in miles
    
    # convert degrees to radians
    lat1, lon1, lat2, lon2 = map(np.deg2rad, [lat1, lon1, lat2, lon2])

    # calculate the difference in latitude and longitude
    dlat = lat2 - lat1 
    dlon = lon2 - lon1  

    # apply the haversine formula
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))

    # calculate the distance in miles
    total_miles = MILES * c
    return total_miles

# %%
# Function to compute pairwise Euclidean distance using a for-loop
def haversine_looping_all(df):
    n = len(df)
    distance_matrix = np.zeros((n, n))  
    
    for i in range(n): # to iterate through the rows of the dataframe
        for j in range(i + 1, n):  
            d = haversine(coordinates[i][0], coordinates[i][1],
                         coordinates[j][0], coordinates[j][1])
            distance_matrix[i][j] = d
            distance_matrix[j][i] = d  # since the distance matrix is symmetric, copy to (j, i)

    
    return distance_matrix


# 1. Measure execution time for for-loop approach
start_time = time.time()
distances_loop = haversine_looping_all(coordinates)
time_loop = time.time() - start_time

print(time_loop)



"""
# Measure execution time for Scipy's cdist function
start_time = time.time()
distances_scipy = cdist(coordinates, coordinates, metric='euclidean')
time_scipy = time.time() - start_time

print(time_scipy)
"""
# Out:
# 0.0030770301818847656
# "\n# Measure execution time for Scipy's cdist function\nstart_time = time.time()\ndistances_scipy = cdist(coordinates, coordinates, metric='euclidean')\ntime_scipy = time.time() - start_time\n\nprint(time_scipy)\n"

# %%
# 2. Measure execution time for NumPy vectorized approach
# Measure execution time for NumPy vectorized approach
def haversine_numpy(coordinates):
    start_time = time.time()
    # to convert the coordinates to column vectors
    lat1 = np.column_stack((coordinates[:, 0]))[:, np.newaxis]
    lon1 = np.column_stack((coordinates[:, 1]))[:, np.newaxis]
    lat2 = np.column_stack((coordinates[:, 0]))[np.newaxis, :]
    lon2 = np.column_stack((coordinates[:, 1]))[np.newaxis, :]

    distances_numpy = haversine(lat1, lon1, lat2, lon2)


    time_numpy = time.time() - start_time
    return  distances_numpy, time_numpy

distances_numpy, time_numpy = haversine_numpy(coordinates)
print(time_numpy)
# Out:
# 0.00018835067749023438

# %%
#3. Measure execution time for Iterrows
def haversine_iterrows(df_cleaned):
    start_time = time.time()
    distances_iterrows = []
    
    # to iterate through the rows of the dataframe
    for index, row in df_cleaned.iterrows():
        distances_iterrows.append(
            haversine(
                row['locLat'], 
                row['locLong'], 
                df_cleaned.loc[index, 'locLat'], 
                df_cleaned.loc[index, 'locLong']
            )
        )
    
    time_iterrows = time.time() - start_time
    return distances_iterrows, time_iterrows

# 調用函數
distances_iterrows, time_iterrows = haversine_iterrows(df_cleaned)
print(time_iterrows)
# Out:
# 0.0011050701141357422

# %%
#4.# Measure execution time for Apply


def haversine_apply(df_cleaned):
    start_time = time.time()
    
    # to use the apply method to calculate the distance
    distances_apply = df_cleaned.apply(
        lambda row: haversine(
            row['locLat'], 
            row['locLong'], 
            df_cleaned.loc[row.name, 'locLat'], 
            df_cleaned.loc[row.name, 'locLong']
        ), 
        axis=1
    )
    
    time_apply = time.time() - start_time
    return distances_apply, time_apply

# to call the function
distances_apply, time_apply = haversine_apply(df_cleaned)
print(time_apply)
# Out:
# 0.0007009506225585938

# %%
#5. Measure execution time for Vectorized functions in Pandas


def haversine_pandas_vectorized(df_cleaned):
    start_time = time.time()
    
    # to convert the locLat and locLong to column vectors
    lat1 = df_cleaned['locLat'].values[:, None]  
    lon1 = df_cleaned['locLong'].values[:, None] 
    lat2 = df_cleaned['locLat'].values[None, :] 
    lon2 = df_cleaned['locLong'].values[None, :]  
    
    # to calculate the distance matrix
    distances_vectorized = haversine(lat1, lon1, lat2, lon2)
    
    time_vectorized = time.time() - start_time
    return distances_vectorized, time_vectorized

# to call the function
distances_vectorized, time_vectorized = haversine_pandas_vectorized(df_cleaned)
print(time_vectorized)
# Out:
# 0.0003142356872558594

# %%
# cProfile to analyze the performance of the for-loop approach
print("\n=== For-loop Approach Performance Analysis ===")
cProfile.run("haversine_looping_all(coordinates)")
print(f"For-loop execution time: {time_loop:.6f} seconds")
# Out:
# === For-loop Approach Performance Analysis ===
#          441 function calls in 0.002 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 2830128831.py:2(haversine_looping_all)
#       435    0.002    0.000    0.002    0.000 556031297.py:3(haversine)
#         1    0.000    0.000    0.002    0.002 <string>:1(<module>)
#         1    0.000    0.000    0.002    0.002 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# For-loop execution time: 0.003077 seconds

# %%
# 2. NumPy vectorized approach analysis
print("\n=== NumPy Vectorized Approach Performance Analysis ===")
cProfile.run("haversine_numpy(coordinates)")
print(f"NumPy vectorized execution time: {time_numpy:.6f} seconds")
# Out:
# === NumPy Vectorized Approach Performance Analysis ===
#          387 function calls in 0.001 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 4027235859.py:3(haversine_numpy)
#         1    0.001    0.001    0.001    0.001 556031297.py:3(haversine)
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#         4    0.000    0.000    0.000    0.000 _shape_base_impl.py:629(_column_stack_dispatcher)
#         4    0.000    0.000    0.000    0.000 _shape_base_impl.py:633(column_stack)
#         4    0.000    0.000    0.000    0.000 multiarray.py:161(concatenate)
#         4    0.000    0.000    0.000    0.000 shape_base.py:209(_arrays_for_stack_dispatcher)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       120    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#       120    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#       120    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# NumPy vectorized execution time: 0.000188 seconds

# %%
# 3. Iterrows approach analysis
print("\n=== Iterrows Approach Performance Analysis ===")
cProfile.run("haversine_iterrows(df_cleaned)")
print(f"Iterrows execution time: {time_iterrows:.6f} seconds")
# Out:
# === Iterrows Approach Performance Analysis ===
#          7457 function calls (7333 primitive calls) in 0.002 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 1192267385.py:2(haversine_iterrows)
#        30    0.000    0.000    0.000    0.000 556031297.py:3(haversine)
#         1    0.000    0.000    0.002    0.002 <string>:1(<module>)
#        91    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#        60    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#        60    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#         1    0.000    0.000    0.000    0.000 base.py:378(interleaved_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:397(ensure_np_dtype)
#       120    0.000    0.000    0.000    0.000 base.py:6312(_index_as_unique)
#        60    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#        60    0.000    0.000    0.000    0.000 base.py:7593(ensure_index)
#        30    0.000    0.000    0.000    0.000 base.py:7688(maybe_extract_name)
#         2    0.000    0.000    0.000    0.000 base.py:82(shape)
#         6    0.000    0.000    0.000    0.000 base.py:84(<genexpr>)
#        30    0.000    0.000    0.000    0.000 base.py:86(_validate_set_axis)
#       122    0.000    0.000    0.000    0.000 base.py:909(__len__)
#         3    0.000    0.000    0.000    0.000 blocks.py:2586(get_values)
#        30    0.000    0.000    0.000    0.000 blocks.py:2645(maybe_coerce_values)
#         3    0.000    0.000    0.000    0.000 blocks.py:266(mgr_locs)
#        30    0.000    0.000    0.000    0.000 blocks.py:2674(get_block_type)
#        30    0.000    0.000    0.000    0.000 blocks.py:2716(new_block)
#        30    0.000    0.000    0.000    0.000 cast.py:1157(maybe_infer_to_datetimelike)
#         1    0.000    0.000    0.000    0.000 cast.py:1392(np_find_common_type)
#         1    0.000    0.000    0.000    0.000 cast.py:1433(find_common_type)
#         4    0.000    0.000    0.000    0.000 cast.py:1463(<genexpr>)
#         2    0.000    0.000    0.000    0.000 cast.py:1472(<genexpr>)
#         2    0.000    0.000    0.000    0.000 cast.py:1474(<genexpr>)
#         4    0.000    0.000    0.000    0.000 cast.py:1479(<genexpr>)
#        30    0.000    0.000    0.000    0.000 common.py:1571(validate_all_hashable)
#        60    0.000    0.000    0.000    0.000 common.py:1590(<genexpr>)
#       180    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#        30    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#        30    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#        30    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#        30    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#        30    0.000    0.000    0.000    0.000 config.py:635(_get_root)
#        30    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#        30    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#        30    0.000    0.000    0.000    0.000 construction.py:416(extract_array)
#        30    0.000    0.000    0.000    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#        30    0.000    0.000    0.000    0.000 construction.py:517(sanitize_array)
#        30    0.000    0.000    0.000    0.000 construction.py:696(_sanitize_ndim)
#        30    0.000    0.000    0.000    0.000 construction.py:735(_sanitize_str_dtypes)
#        30    0.000    0.000    0.000    0.000 construction.py:758(_maybe_repeat)
#        30    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#        30    0.000    0.000    0.000    0.000 flags.py:55(allows_duplicate_labels)
#        30    0.000    0.000    0.000    0.000 flags.py:87(allows_duplicate_labels)
#       120    0.000    0.000    0.000    0.000 frame.py:1030(axes)
#         1    0.000    0.000    0.000    0.000 frame.py:12590(values)
#        31    0.000    0.000    0.001    0.000 frame.py:1505(iterrows)
#        60    0.000    0.000    0.000    0.000 frame.py:4191(_get_value)
#        60    0.000    0.000    0.000    0.000 frame.py:4626(_get_item_cache)
#        30    0.000    0.000    0.000    0.000 generic.py:278(__init__)
#        30    0.000    0.000    0.000    0.000 generic.py:363(attrs)
#        60    0.000    0.000    0.000    0.000 generic.py:37(_check)
#        60    0.000    0.000    0.000    0.000 generic.py:405(flags)
#        60    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#        30    0.000    0.000    0.000    0.000 generic.py:6236(__finalize__)
#        30    0.000    0.000    0.000    0.000 generic.py:6284(__getattr__)
#        30    0.000    0.000    0.000    0.000 generic.py:6301(__setattr__)
#        60    0.000    0.000    0.000    0.000 generic.py:696(ndim)
#        30    0.000    0.000    0.000    0.000 generic.py:807(_set_axis)
#        60    0.000    0.000    0.001    0.000 indexing.py:1176(__getitem__)
#       180    0.000    0.000    0.000    0.000 indexing.py:1180(<genexpr>)
#       180    0.000    0.000    0.000    0.000 indexing.py:1181(<genexpr>)
#        60    0.000    0.000    0.000    0.000 indexing.py:1251(_is_scalar_access)
#       120    0.000    0.000    0.000    0.000 indexing.py:2765(check_dict_or_set_indexers)
#       180    0.000    0.000    0.000    0.000 indexing.py:2772(<genexpr>)
#       180    0.000    0.000    0.000    0.000 indexing.py:2781(<genexpr>)
#        60    0.000    0.000    0.000    0.000 indexing.py:305(loc)
#        60    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         1    0.000    0.000    0.000    0.000 managers.py:1633(as_array)
#         1    0.000    0.000    0.000    0.000 managers.py:1707(_interleave)
#         1    0.000    0.000    0.000    0.000 managers.py:1721(<listcomp>)
#        30    0.000    0.000    0.000    0.000 managers.py:1837(__init__)
#        30    0.000    0.000    0.000    0.000 managers.py:1863(from_array)
#        30    0.000    0.000    0.000    0.000 managers.py:1940(_block)
#       120    0.000    0.000    0.000    0.000 managers.py:2004(internal_values)
#        30    0.000    0.000    0.000    0.000 managers.py:236(set_axis)
#         1    0.000    0.000    0.000    0.000 managers.py:241(is_single_block)
#        30    0.000    0.000    0.000    0.000 multiarray.py:1101(copyto)
#         1    0.000    0.000    0.000    0.000 multiarray.py:684(result_type)
#        30    0.000    0.000    0.000    0.000 numeric.py:303(full)
#        60    0.000    0.000    0.000    0.000 range.py:380(is_unique)
#        60    0.000    0.000    0.000    0.000 range.py:408(get_loc)
#        31    0.000    0.000    0.000    0.000 range.py:463(__iter__)
#         2    0.000    0.000    0.000    0.000 range.py:999(__len__)
#        60    0.000    0.000    0.000    0.000 series.py:1095(__getitem__)
#        60    0.000    0.000    0.000    0.000 series.py:1220(_get_value)
#        30    0.000    0.000    0.000    0.000 series.py:1480(_clear_item_cache)
#        30    0.000    0.000    0.001    0.000 series.py:389(__init__)
#        30    0.000    0.000    0.000    0.000 series.py:734(name)
#        30    0.000    0.000    0.000    0.000 series.py:784(name)
#       120    0.000    0.000    0.000    0.000 series.py:831(_values)
#        30    0.000    0.000    0.000    0.000 typing.py:1737(cast)
#        32    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#       122    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#       180    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.002    0.002 {built-in method builtins.exec}
#       150    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        60    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#      1925    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        60    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#   491/367    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#        30    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#        31    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#        30    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        60    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        60    0.000    0.000    0.000    0.000 {method 'index' of 'range' objects}
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        30    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#
#
# Iterrows execution time: 0.001105 seconds

# %%
# 4. Apply approach analysis
print("\n=== Apply Approach Performance Analysis ===")
cProfile.run("haversine_apply(df_cleaned)")
print(f"Apply execution time: {time_apply:.6f} seconds")
# Out:
# === Apply Approach Performance Analysis ===
#          4843 function calls (4825 primitive calls) in 0.005 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.005    0.005 3676287989.py:4(haversine_apply)
#        30    0.000    0.000    0.003    0.000 3676287989.py:9(<lambda>)
#        30    0.000    0.000    0.000    0.000 556031297.py:3(haversine)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#         1    0.000    0.000    0.005    0.005 <string>:1(<module>)
#        60    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#        60    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         4    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#         1    0.000    0.000    0.005    0.005 apply.py:1061(apply_standard)
#         1    0.000    0.000    0.004    0.004 apply.py:1070(apply_series_generator)
#         1    0.000    0.000    0.001    0.001 apply.py:1102(wrap_results)
#         1    0.000    0.000    0.000    0.000 apply.py:121(__init__)
#        31    0.000    0.000    0.001    0.000 apply.py:1247(series_generator)
#         1    0.000    0.000    0.000    0.000 apply.py:1329(result_index)
#         1    0.000    0.000    0.000    0.000 apply.py:1643(reconstruct_func)
#         2    0.000    0.000    0.000    0.000 apply.py:717(index)
#         1    0.000    0.000    0.000    0.000 apply.py:773(__init__)
#         1    0.000    0.000    0.000    0.000 apply.py:82(frame_apply)
#         1    0.000    0.000    0.000    0.000 apply.py:856(columns)
#         1    0.000    0.000    0.000    0.000 apply.py:860(values)
#         1    0.000    0.000    0.005    0.005 apply.py:864(apply)
#         2    0.000    0.000    0.000    0.000 base.py:332(array)
#        60    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#         2    0.000    0.000    0.000    0.000 base.py:378(interleaved_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:397(ensure_np_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:475(__new__)
#         2    0.000    0.000    0.000    0.000 base.py:540(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:591(_ensure_array)
#         1    0.000    0.000    0.000    0.000 base.py:609(_dtype_to_subclass)
#       120    0.000    0.000    0.000    0.000 base.py:6312(_index_as_unique)
#         1    0.000    0.000    0.000    0.000 base.py:649(_simple_new)
#        60    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:74(__len__)
#         4    0.000    0.000    0.000    0.000 base.py:7593(ensure_index)
#         3    0.000    0.000    0.000    0.000 base.py:7688(maybe_extract_name)
#         2    0.000    0.000    0.000    0.000 base.py:82(shape)
#         1    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#         6    0.000    0.000    0.000    0.000 base.py:84(<genexpr>)
#         3    0.000    0.000    0.000    0.000 base.py:86(_validate_set_axis)
#        12    0.000    0.000    0.000    0.000 base.py:909(__len__)
#        21    0.000    0.000    0.000    0.000 blocks.py:1253(iget)
#         3    0.000    0.000    0.000    0.000 blocks.py:2586(get_values)
#         1    0.000    0.000    0.000    0.000 blocks.py:2645(maybe_coerce_values)
#         6    0.000    0.000    0.000    0.000 blocks.py:266(mgr_locs)
#         2    0.000    0.000    0.000    0.000 blocks.py:2674(get_block_type)
#         2    0.000    0.000    0.000    0.000 blocks.py:2716(new_block)
#         1    0.000    0.000    0.000    0.000 blocks.py:718(dtype)
#         2    0.000    0.000    0.000    0.000 cast.py:124(maybe_convert_platform)
#         2    0.000    0.000    0.000    0.000 cast.py:1392(np_find_common_type)
#         2    0.000    0.000    0.000    0.000 cast.py:1433(find_common_type)
#         8    0.000    0.000    0.000    0.000 cast.py:1463(<genexpr>)
#         4    0.000    0.000    0.000    0.000 cast.py:1472(<genexpr>)
#         4    0.000    0.000    0.000    0.000 cast.py:1474(<genexpr>)
#         8    0.000    0.000    0.000    0.000 cast.py:1479(<genexpr>)
#         2    0.000    0.000    0.000    0.000 cast.py:1580(construct_1d_object_array_from_listlike)
#         1    0.000    0.000    0.000    0.000 common.py:1081(is_numeric_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:126(_classes_and_not_datetimelike)
#         1    0.000    0.000    0.000    0.000 common.py:131(<lambda>)
#         2    0.000    0.000    0.000    0.000 common.py:1331(is_ea_or_datetimelike_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1434(_is_dtype_type)
#         2    0.000    0.000    0.000    0.000 common.py:1571(validate_all_hashable)
#         4    0.000    0.000    0.000    0.000 common.py:1590(<genexpr>)
#         1    0.000    0.000    0.000    0.000 common.py:301(maybe_iterable_to_list)
#       180    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#         1    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#         4    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#         2    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#         2    0.000    0.000    0.000    0.000 config.py:153(_set_option)
#         1    0.000    0.000    0.000    0.000 config.py:471(__init__)
#         1    0.000    0.000    0.000    0.000 config.py:479(__enter__)
#         1    0.000    0.000    0.000    0.000 config.py:480(<listcomp>)
#         1    0.000    0.000    0.000    0.000 config.py:485(__exit__)
#         4    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#         4    0.000    0.000    0.000    0.000 config.py:635(_get_root)
#         5    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#         2    0.000    0.000    0.000    0.000 config.py:665(_get_registered_option)
#         4    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#         1    0.000    0.000    0.000    0.000 config.py:688(_warn_if_deprecated)
#         2    0.000    0.000    0.000    0.000 config.py:886(inner)
#         2    0.000    0.000    0.000    0.000 construction.py:416(extract_array)
#         4    0.000    0.000    0.000    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#         2    0.000    0.000    0.000    0.000 construction.py:517(sanitize_array)
#         2    0.000    0.000    0.000    0.000 construction.py:688(_sanitize_non_ordered)
#         2    0.000    0.000    0.000    0.000 construction.py:696(_sanitize_ndim)
#         2    0.000    0.000    0.000    0.000 construction.py:735(_sanitize_str_dtypes)
#         2    0.000    0.000    0.000    0.000 construction.py:758(_maybe_repeat)
#         3    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#         2    0.000    0.000    0.000    0.000 flags.py:55(allows_duplicate_labels)
#         2    0.000    0.000    0.000    0.000 flags.py:87(allows_duplicate_labels)
#         1    0.000    0.000    0.005    0.005 frame.py:10170(apply)
#       120    0.000    0.000    0.000    0.000 frame.py:1030(axes)
#         1    0.000    0.000    0.000    0.000 frame.py:1047(shape)
#         1    0.000    0.000    0.000    0.000 frame.py:12590(values)
#         1    0.000    0.000    0.000    0.000 frame.py:3983(_ixs)
#        60    0.000    0.000    0.000    0.000 frame.py:4191(_get_value)
#        60    0.000    0.000    0.000    0.000 frame.py:4626(_get_item_cache)
#         1    0.000    0.000    0.000    0.000 frame.py:678(_constructor_sliced_from_mgr)
#         3    0.000    0.000    0.000    0.000 generic.py:278(__init__)
#         1    0.000    0.000    0.000    0.000 generic.py:339(_from_mgr)
#         2    0.000    0.000    0.000    0.000 generic.py:363(attrs)
#        41    0.000    0.000    0.000    0.000 generic.py:37(_check)
#         4    0.000    0.000    0.000    0.000 generic.py:405(flags)
#        41    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#         1    0.000    0.000    0.000    0.000 generic.py:4379(_set_is_copy)
#         1    0.000    0.000    0.000    0.000 generic.py:572(_get_axis_number)
#         2    0.000    0.000    0.000    0.000 generic.py:6236(__finalize__)
#         2    0.000    0.000    0.000    0.000 generic.py:6284(__getattr__)
#        36    0.000    0.000    0.000    0.000 generic.py:6301(__setattr__)
#        60    0.000    0.000    0.000    0.000 generic.py:696(ndim)
#         3    0.000    0.000    0.000    0.000 generic.py:807(_set_axis)
#        60    0.000    0.000    0.002    0.000 indexing.py:1176(__getitem__)
#       180    0.000    0.000    0.000    0.000 indexing.py:1180(<genexpr>)
#       180    0.000    0.000    0.000    0.000 indexing.py:1181(<genexpr>)
#        60    0.000    0.000    0.000    0.000 indexing.py:1251(_is_scalar_access)
#       120    0.000    0.000    0.001    0.000 indexing.py:2765(check_dict_or_set_indexers)
#       180    0.000    0.000    0.000    0.000 indexing.py:2772(<genexpr>)
#       180    0.000    0.000    0.000    0.000 indexing.py:2781(<genexpr>)
#        60    0.000    0.000    0.000    0.000 indexing.py:305(loc)
#         5    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         1    0.000    0.000    0.000    0.000 inference.py:373(is_sequence)
#         1    0.000    0.000    0.000    0.000 managers.py:1633(as_array)
#         1    0.000    0.000    0.000    0.000 managers.py:1707(_interleave)
#         1    0.000    0.000    0.000    0.000 managers.py:1721(<listcomp>)
#         2    0.000    0.000    0.000    0.000 managers.py:1837(__init__)
#         1    0.000    0.000    0.000    0.000 managers.py:1863(from_array)
#         1    0.000    0.000    0.000    0.000 managers.py:1940(_block)
#         1    0.000    0.000    0.000    0.000 managers.py:1993(dtype)
#       120    0.000    0.000    0.000    0.000 managers.py:2004(internal_values)
#        30    0.000    0.000    0.000    0.000 managers.py:2065(set_values)
#         3    0.000    0.000    0.000    0.000 managers.py:236(set_axis)
#         1    0.000    0.000    0.000    0.000 managers.py:241(is_single_block)
#         1    0.000    0.000    0.000    0.000 managers.py:246(items)
#         2    0.000    0.000    0.000    0.000 managers.py:291(arrays)
#         2    0.000    0.000    0.000    0.000 managers.py:303(<listcomp>)
#         1    0.000    0.000    0.000    0.000 managers.py:958(fast_xs)
#         1    0.000    0.000    0.000    0.000 managers.py:984(<listcomp>)
#         2    0.000    0.000    0.000    0.000 multiarray.py:1101(copyto)
#         2    0.000    0.000    0.000    0.000 multiarray.py:684(result_type)
#         2    0.000    0.000    0.000    0.000 numeric.py:303(full)
#         1    0.000    0.000    0.000    0.000 range.py:1009(__getitem__)
#        60    0.000    0.000    0.000    0.000 range.py:380(is_unique)
#        60    0.000    0.000    0.000    0.000 range.py:408(get_loc)
#        31    0.000    0.000    0.000    0.000 range.py:463(__iter__)
#         4    0.000    0.000    0.000    0.000 range.py:999(__len__)
#        60    0.000    0.000    0.001    0.000 series.py:1095(__getitem__)
#        60    0.000    0.000    0.000    0.000 series.py:1220(_get_value)
#         3    0.000    0.000    0.000    0.000 series.py:1480(_clear_item_cache)
#       2/1    0.000    0.000    0.001    0.001 series.py:389(__init__)
#         1    0.000    0.000    0.001    0.001 series.py:607(_init_dict)
#         1    0.000    0.000    0.000    0.000 series.py:707(dtype)
#        62    0.000    0.000    0.000    0.000 series.py:734(name)
#         2    0.000    0.000    0.000    0.000 series.py:784(name)
#       120    0.000    0.000    0.000    0.000 series.py:831(_values)
#         5    0.000    0.000    0.000    0.000 typing.py:1737(cast)
#         2    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10450afe8}
#         4    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#       124    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#       181    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.005    0.005 {built-in method builtins.exec}
#        48    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#      1208    0.000    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#   153/136    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         3    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        62    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        60    0.000    0.000    0.000    0.000 {method 'index' of 'range' objects}
#         3    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#
#
# Apply execution time: 0.000701 seconds

# %%
# 5. Pandas vectorized approach analysis
print("\n=== Pandas Vectorized Approach Performance Analysis ===")
cProfile.run("haversine_pandas_vectorized(df_cleaned)")
print(f"Pandas vectorized execution time: {time_vectorized:.6f} seconds")
# Out:
# === Pandas Vectorized Approach Performance Analysis ===
#          107 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 3918841675.py:4(haversine_pandas_vectorized)
#         1    0.000    0.000    0.000    0.000 556031297.py:3(haversine)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         8    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#         4    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         4    0.000    0.000    0.000    0.000 base.py:5323(__contains__)
#         4    0.000    0.000    0.000    0.000 blocks.py:249(external_values)
#         4    0.000    0.000    0.000    0.000 blocks.py:2827(external_values)
#         4    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#         4    0.000    0.000    0.000    0.000 frame.py:4062(__getitem__)
#         4    0.000    0.000    0.000    0.000 frame.py:4626(_get_item_cache)
#         4    0.000    0.000    0.000    0.000 indexing.py:2765(check_dict_or_set_indexers)
#         4    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         4    0.000    0.000    0.000    0.000 managers.py:2000(external_values)
#         4    0.000    0.000    0.000    0.000 series.py:789(values)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        32    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#
#
# Pandas vectorized execution time: 0.000314 seconds

# %%
# Tabulate results
execution_times = pd.DataFrame({
    "Method": ["For-loop", "NumPy Vectorized", "Iterrows", "Apply", "Pandas Vectorized"],
    "Execution Time (seconds)": [time_loop, time_numpy, time_iterrows, time_apply, time_vectorized]
})

# Display results
#print(execution_times)

print("----------------------------------------------------------------------------------------")


# sort the execution time
execution_times = execution_times.sort_values("Execution Time (seconds)")

# Display results  after sorting
print(execution_times)
# Out:
# ----------------------------------------------------------------------------------------
#               Method  Execution Time (seconds)
# 1   NumPy Vectorized                  0.000188
# 4  Pandas Vectorized                  0.000314
# 3              Apply                  0.000701
# 2           Iterrows                  0.001105
# 0           For-loop                  0.003077
