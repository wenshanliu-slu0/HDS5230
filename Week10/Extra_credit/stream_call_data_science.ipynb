# %%
import requests
import json
import numpy as np

# %%
PREDICT_URL = "http://127.0.0.1:8000/predict/"
RESULT_URL = "http://127.0.0.1:8000/result/"
RETRAIN_URL = "http://127.0.0.1:8000/retrain/"
NEWMODEL_URL = "http://127.0.0.1:8000/new_model/"
EVALUATE_URL = "http://127.0.0.1:8000/evaluate_model/"    

DUMMY_MODEL = "Dummy"
KNN_MODEL = "KNN"

metric = 0.0
key = 0

# %%
def send_get_request (url:str, params:dict) :

    data = {}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        print(data)
    else:
        print(f"Error: {response.status_code}")
    return data

# %%
def get_prediction(key, x, y) :
    params = {"id" : key, "x" :x, "y" :y}
    response = send_get_request(PREDICT_URL, params)
    return response.get("prediction")

# %%
def send_result(key, result) :
    params = {"id" : key, "result" : result}
    print("result", result)
    response = send_get_request(RESULT_URL, params)
    return response

# %%
def request_retrain(last_n:int) :
    params = {"last_n" : last_n}
    response = send_get_request(RETRAIN_URL, params)
    return response

# %%
def request_new_model(model_name:str, model_params:dict, last_n:int) :
    params = {"last_n" : last_n, "model_str": model_name}
    for key, value in model_params.items():
        params[key] = value
    response = send_get_request(NEWMODEL_URL, params)
    return response

# %%
def request_evaluation(last_n:int) :
    params = {"last_n" : last_n}
    response = send_get_request(EVALUATE_URL, params)
    return response

# %%
def new_dummy(strategy: str, last_n: int) :
    model_params = {"strategy" : strategy}
    response = request_new_model(DUMMY_MODEL, model_params, last_n) 
    return response

# %%
def new_knn(k:int, last_n: int):
    model_params = {"k" : k}
    response = request_new_model(KNN_MODEL, model_params, last_n)
    return response

# %%
def item(key,metric) :
    key=key+1
    x=np.random.rand()*2-1
    y=np.random.rand()*2-1
    z=np.random.rand()*.2-.1
    result=x*y+z>metric
    return [key, x, y, result]

# %%
for i in range(200):
    key, x, y, result = item(key, metric)

    prediction = get_prediction(key, x, y)
    send_result(key, result)

# new_dummy("stratified", 80)
new_knn(5, 150)
# Out:
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 1'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 2'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 3'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 4'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 5'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 6'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 7'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 8'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 9'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 10'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 11'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 12'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 13'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 14'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 15'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 16'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 17'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 18'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 19'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 20'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 21'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 22'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 23'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 24'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 25'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 26'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 27'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 28'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 29'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 30'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 31'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 32'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 33'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 34'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 35'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 36'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 37'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 38'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 39'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 40'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 41'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 42'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 43'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 44'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 45'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 46'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 47'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 48'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 49'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 50'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 51'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 52'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 53'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 54'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 55'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 56'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 57'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 58'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 59'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 60'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 61'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 62'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 63'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 64'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 65'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 66'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 67'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 68'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 69'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 70'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 71'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 72'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 73'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 74'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 75'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 76'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 77'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 78'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 79'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 80'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 81'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 82'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 83'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 84'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 85'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 86'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 87'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 88'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 89'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 90'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 91'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 92'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 93'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 94'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 95'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 96'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 97'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 98'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 99'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 100'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 101'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 102'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 103'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 104'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 105'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 106'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 107'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 108'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 109'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 110'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 111'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 112'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 113'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 114'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 115'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 116'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 117'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 118'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 119'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 120'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 121'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 122'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 123'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 124'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 125'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 126'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 127'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 128'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 129'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 130'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 131'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 132'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 133'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 134'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 135'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 136'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 137'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 138'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 139'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 140'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 141'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 142'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 143'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 144'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 145'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 146'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 147'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 148'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 149'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 150'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 151'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 152'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 153'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 154'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 155'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 156'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 157'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 158'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 159'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 160'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 161'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 162'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 163'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 164'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 165'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 166'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 167'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 168'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 169'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 170'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 171'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 172'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 173'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 174'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 175'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 176'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 177'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 178'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 179'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 180'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 181'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 182'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 183'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 184'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 185'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 186'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 187'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 188'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 189'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 190'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 191'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 192'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 193'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 194'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 195'}
# {'prediction': 'True'}
# result False
# {'message': 'Copied result for 196'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 197'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 198'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 199'}
# {'prediction': 'True'}
# result True
# {'message': 'Copied result for 200'}
# {'message': 'Model trained KNeighborsClassifier()', 'train': {'message': 'Model retrained', 'accuracy': 0.9166666666666666, 'recall': 0.9117647058823529, 'precision': 0.9393939393939394}}
# {'message': 'Model trained KNeighborsClassifier()',
#  'train': {'message': 'Model retrained',
#   'accuracy': 0.9166666666666666,
#   'recall': 0.9117647058823529,
#   'precision': 0.9393939393939394}}

# %%
# FastAPI endpoint definition (example)
# @app.post("/items/")
# async def create_item(item: Item):
#     return item

#url = "http://127.0.0.1:8000/items/"  # Replace with your actual URL
#data = {"name": "New Item", "description": "A new item description"}
#headers = {'Content-type': 'application/json'}
#response = requests.post(url, data=json.dumps(data), headers=headers)

#if response.status_code == 200:
#    data = response.json()
#    print(data)
#else:
#    print(f"Error: {response.status_code}")
